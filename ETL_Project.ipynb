# %%
#import dependencies
import pandas as pd
from sqlalchemy import create_engine, inspect
from sqlalchemy import Column, Integer, String, Float

# %%
#csv files
gdp_file = 'GDP.csv'
unrate_file = 'UNRATE.csv'

# %%
#GDP
gdp = pd.read_csv(gdp_file)
gdp = gdp.dropna()

# %%
#Munge GDP Data
gdp_clean = gdp[['realtime_start','date','value']].copy()
gdp_clean = gdp_clean.rename({'value':'gdp_value'},axis=1)
gdp_clean.head()
# Out:
#   realtime_start        date  gdp_value
# 0     1992-12-22  1946-01-01      199.7
# 2     1997-05-07  1946-01-01      210.4
# 4     1992-12-22  1946-04-01      207.7
# 6     1997-05-07  1946-04-01      218.5
# 8     1992-12-22  1946-07-01      217.9

# %%
#Unemployment Rate
unemploy = pd.read_csv(unrate_file)
unemploy = unemploy.dropna()

# %%
un_clean = unemploy

# %%
un_clean.head()
# Out:
#    Unnamed: 0 realtime_start        date  value
# 0           0     1960-03-15  1948-01-01    3.5
# 1           1     1966-02-08  1948-01-01    3.4
# 2           2     1960-03-15  1948-02-01    3.8
# 3           3     1966-02-08  1948-02-01    3.9
# 4           4     1967-02-09  1948-02-01    3.8

# %%
##Create engine - connection to Postgresql
engine = create_engine('postgresql://postgres:barbat709@localhost:5432/GDP')
connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...

# %%
## Inspect if DB has tables
inspector = inspect(engine)
table_list = inspector.get_table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...

# %%
#table_list

# %%
## Table names for Pandas Dataframes
our_tables = ['GDP_TABLE', 'UN_TABLE']

# %%
for each in our_tables:
    if each not in table_list:
        gdp_clean.to_sql(each, engine) ### Crate table if table doesn't exist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-feb8677cce24> in <module>
#       1 for each in our_tables:
# ----> 2     if each not in table_list:
#       3         gdp_clean.to_sql(each, engine) ### Crate table if table doesn't exist
#
# NameError: name 'table_list' is not defined

# %%
## Query elements in SQL created view
query0 = 'SELECT * FROM public."Economy_Blah"'

# %%
## Organize View Query into Pandas Dataframe
Blah_DF = pd.read_sql_query(query0, engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...

# %%
Blah_DF.rename({'value':'unemploy_value'})
Blah_DF.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-13f3748c68f0> in <module>
# ----> 1 Blah_DF.rename({'value':'unemploy_value'})
#       2 Blah_DF.head(50)
#
# NameError: name 'Blah_DF' is not defined
